# %%
# View the data

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia-340-2025-fall-riley12345/San_Francisco_AI_Use_Inventory__Chapter_22J_.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#                                               id department  \
# 0  DPH-Evolv Express concealed weapons detection        DPH
# 1                       DPH-Ischemaview Rapid AI        DPH
# 2                                      DPH-Mirai        DPH
# 3                                    DPH-TalView        DPH
# 4                   DPH-TransMed Inspirata Epath        DPH
#
#                          q1_tool_vendor_name  \
# 0  Evolv Express concealed weapons detection
# 1                       Ischemaview Rapid AI
# 2                                      Mirai
# 3                                    TalView
# 4                   TransMed Inspirata Epath
#
#                                          q2_ purpose  \
# 0  Evolv Express is a next-generation, AI-powered...
# 1  Rapid AI is used to identify and guide treatme...
# 2  Mirai is an AI tool that identifies high-risk ...
# 3  TalView’s AI proctoring tool is designed to mo...
# 4  This tool is a rule-based system that automate...
#
#                                      q3_intended_use  \
# 0  Concealed weapons (guns and knives) detection ...
# 1  The tool is intended for any individual (inpat...
# 2  The tool is intended for women age 30 and olde...
# 3  The tool is intended for use by HR and proctor...
# 4  The technology is intended to process diagnost...
#
#                                           q4_context  \
# 0  The weapons detection system is a part of the ...
# 1  Rapid AI integrates into clinical stroke workf...
# 2  Mirai is integrated into existing mammography ...
# 3  The technology is deployed in the context of r...
# 4  Within the existing pathology reporting workfl...
#
#                                    q5_ training_data  \
# 0  According to the Evolv website, the "AI model ...
# 1  The system is a clinically oriented radiologic...
# 2  Mirai was trained on mammograms from a large, ...
# 3  The model is trained on extensive, anonymized,...
# 4  The tool uses rule-based natural language proc...
#
#                                      q6_how_it_works  \
# 0  It combines advanced sensor technology, real-t...
# 1  Rapid AI automatically processes CT or MRI per...
# 2  Mirai uses deep learning to transform each mam...
# 3  TalView operates by capturing video, audio, an...
# 4  This AI engine employs rule-based natural lang...
#
#                                       q7_output_data  \
# 0  Weapon signatures and images collected on site...
# 1  Rapid AI generates user-friendly scans highlig...
# 2  The model instantly generates a risk score/per...
# 3  During each exam, the system generates detaile...
# 4  The system generates real-time alerts or flags...
#
#                             q8_optimization_accuracy  ...  \
# 0  Internally, Express uses machine learning mode...  ...
# 1  Rapid AI is primarily aimed at reducing the ti...  ...
# 2  Mirai aims to shorten wait times for high-risk...  ...
# 3  The technology is optimized to identify and fl...  ...
# 4  This technology aims to identify and capture a...  ...
#
#                                  q15_human_oversight  \
# 0  Evolv system will alert security staff of the ...
# 1  Clinicians ultimately decide on diagnosing and...
# 2  Clinicians continue reading mammograms as usua...
# 3  The system is implemented with robust human ov...
# 4  Human oversight occurs throughout the process,...
#
#                          q16_data_reuse_for_training  \
# 0  DPH does not allow personally identifiable inf...
# 1  DPH does not allow personally identifiable inf...
# 2  DPH does not allow personally identifiable inf...
# 3  DPH does not allow personally identifiable inf...
# 4  DPH does not allow personally identifiable inf...
#
#                                            q17_users  \
# 0  Intended users are the San Francisco Sheriff’s...
# 1  Individuals presenting with stroke symptoms co...
# 2  This includes women 30+ coming for mammograms ...
# 3  The technology interacts primarily with job ca...
# 4  The primary patient community includes those w...
#
#                          q18_public_or_worker_impact  \
# 0  ZSFG has developed multiple workplace safety i...
# 1  The use of Rapid AI exclusively affects stroke...
# 2  Since only select high-risk patients receive e...
# 3  While the system generates AI flags that guide...
# 4  The tool’s core function is to ensure accurate...
#
#                                    q19_accessibility  \
# 0  For all SFDPH users who require assistive tech...
# 1  For any SFDPH staff requiring assistive techno...
# 2  For SFDPH staff requiring assistive technologi...
# 3  For users requiring assistive technologies, th...
# 4  For all SFDPH users who require assistive tech...
#
#                                       q20_job_impact  \
# 0                                                No.
# 1  This technology is not expected to replace any...
# 2  There is no indication of staff replacement. M...
# 3  The technology is not expected to replace any ...
# 4  This technology is not expected to replace any...
#
#                            q21_why_the_city_needs_it  \
# 0  The weapons detection system is a part of the ...
# 1  Maintaining a Joint Commission stroke certific...
# 2  By offering faster diagnostic imaging for high...
# 3  Implementing TalView’s AI proctoring system is...
# 4  The tool supports SFDPH objectives by improvin...
#
#                            q22_risks_and_mitigations  data_as_of  \
# 0  The potential “harms” from a false positive de...  2025/07/15
# 1  Potential risks center on incomplete imaging d...  2025/07/15
# 2  Potential risks include labeling too many pati...  2025/07/15
# 3  The primary risk is the potential for non-prob...  2025/07/15
# 4  The main risks involve missed or inaccurate ca...  2025/07/15
#
#   data_loaded_at
# 0     2025/07/18
# 1     2025/07/18
# 2     2025/07/18
# 3     2025/07/18
# 4     2025/07/18
#
# [5 rows x 26 columns]

# %%
df.shape #show the number of rows and columns
# Out:
# (28, 26)

# %%
df['department'] #select a column
# Out:
# 0         DPH
# 1         DPH
# 2         DPH
# 3         DPH
# 4         DPH
# 5         DPH
# 6       SFPUC
# 7       SFPUC
# 8       SFPUC
# 9       SFPUC
# 10      SFPUC
# 11      SFPUC
# 12      SFPUC
# 13      SFPUC
# 14      SFPUC
# 15      SFPUC
# 16      SFPUC
# 17      SFPUC
# 18      SFPUC
# 19      SFPUC
# 20    ADM-311
# 21        POL
# 22        POL
# 23        POL
# 24        POL
# 25        POL
# 26        POL
# 27        DPH
# Name: department, dtype: object

# %%
df.sort_values(by='department') #sort data by a column
# Out:
#                                                    id department  \
# 20      ADM-311-Connected Bits LLC - SF311 Mobile App    ADM-311
# 0       DPH-Evolv Express concealed weapons detection        DPH
# 5   DPH-ZSFG 30 Day Unplanned Heart Failure Readmi...        DPH
# 4                        DPH-TransMed Inspirata Epath        DPH
# 27                     DPH-360 Encompass 3M/Solventum        DPH
# 2                                           DPH-Mirai        DPH
# 1                            DPH-Ischemaview Rapid AI        DPH
# 3                                         DPH-TalView        DPH
# 25                        POL-Motorola Solutions Inc.        POL
# 24                        POL-Motorola Solutions Inc.        POL
# 23                                           POL-Axon        POL
# 22                                  POL-VIQ Solutions        POL
# 21                                        POL-PenLink        POL
# 26                                    POL-ShotSpotter        POL
# 19              SFPUC-YouTube\n(Google/Alphabet Inc.)      SFPUC
# 18                         SFPUC-X (Formerly Twitter)      SFPUC
# 17                             SFPUC-Skydio 10X Drone      SFPUC
# 16                                     SFPUC-Nextdoor      SFPUC
# 14                       SFPUC-LinkedIn \n(Microsoft)      SFPUC
# 12                                    SFPUC-Hootsuite      SFPUC
# 11               SFPUC-G Translate | Google Translate      SFPUC
# 10                                SFPUC-Form Assembly      SFPUC
# 9                             SFPUC-Facebook \n(Meta)      SFPUC
# 8   SFPUC-DJI Drones (9)\n(Mavric 2 Pro (QTY 2), M...      SFPUC
# 7                                        SFPUC-ArcGIS      SFPUC
# 6                             SFPUC-Anzu Raptor Drone      SFPUC
# 15                                    SFPUC-Muck Rack      SFPUC
# 13                           SFPUC-Instagram \n(Meta)      SFPUC
#
#                                   q1_tool_vendor_name  \
# 20              Connected Bits LLC - SF311 Mobile App
# 0           Evolv Express concealed weapons detection
# 5   ZSFG 30 Day Unplanned Heart Failure Readmissio...
# 4                            TransMed Inspirata Epath
# 27                         360 Encompass 3M/Solventum
# 2                                               Mirai
# 1                                Ischemaview Rapid AI
# 3                                             TalView
# 25                            Motorola Solutions Inc.
# 24                            Motorola Solutions Inc.
# 23                                               Axon
# 22                                      VIQ Solutions
# 21                                            PenLink
# 26                                        ShotSpotter
# 19                    YouTube\n(Google/Alphabet Inc.)
# 18                               X (Formerly Twitter)
# 17                                   Skydio 10X Drone
# 16                                           Nextdoor
# 14                             LinkedIn \n(Microsoft)
# 12                                          Hootsuite
# 11                     G Translate | Google Translate
# 10                                      Form Assembly
# 9                                   Facebook \n(Meta)
# 8   DJI Drones (9)\n(Mavric 2 Pro (QTY 2), Matrice...
# 7                                              ArcGIS
# 6                                   Anzu Raptor Drone
# 15                                          Muck Rack
# 13                                 Instagram \n(Meta)
#
#                                           q2_ purpose  \
# 20                                                NaN
# 0   Evolv Express is a next-generation, AI-powered...
# 5   This tool predicts 30-day unplanned readmissio...
# 4   This tool is a rule-based system that automate...
# 27  This tool addresses coding and documentation i...
# 2   Mirai is an AI tool that identifies high-risk ...
# 1   Rapid AI is used to identify and guide treatme...
# 3   TalView’s AI proctoring tool is designed to mo...
# 25  It is designed for law enforcement to track ve...
# 24  Motorola Solutions VM Assist technology is a L...
# 23  Redaction Assistant - A tool integrated into A...
# 22  aiAssist generates speech recognition drafts a...
# 21  ï PenLink, Ltd provides state-of-the-art softw...
# 26  ShotSpotter is an acoustic gunshot detection s...
# 19  Video-sharing platform for uploading, viewing,...
# 18  A social media platform that is known as a 'mi...
# 17  Drones are designed to provide aerial imaging,...
# 16  Nextdoor’s purpose is to foster community conn...
# 14  Social media platform for professional and car...
# 12  Hootsuite is a social media management platfor...
# 11  G Translate is used to provide automated, real...
# 10  Form Assembly is a web-based form platform tha...
# 9   Facebook as a real-time communication tool to ...
# 8   DJI drones are designed to provide aerial imag...
# 7   ArcGIS helps organizations understand patterns...
# 6   Drones are designed to provide aerial imaging,...
# 15  Muck Rack functions include monitoring news co...
# 13  Instagram is a visual communication platform t...
#
#                                       q3_intended_use  \
# 20                                                NaN
# 0   Concealed weapons (guns and knives) detection ...
# 5   The model is meant for inpatient and outpatien...
# 4   The technology is intended to process diagnost...
# 27  The technology is intended for use by coders, ...
# 2   The tool is intended for women age 30 and olde...
# 1   The tool is intended for any individual (inpat...
# 3   The tool is intended for use by HR and proctor...
# 25  Its primary purpose is to streamline vehicle t...
# 24  The main use of the technology is to streamlin...
# 23  Axonís suite of AI-powered toolsóRedaction Ass...
# 22  To make transcription more efficient by provid...
# 21  ï Rapidly convert lawfully authorized collecte...
# 26  To assist law enforcement in responding rapidl...
# 19  Public video communication, education, outreac...
# 18  X (formerly Twitter) as a platform for communi...
# 17  Drones are designed to provide aerial imaging,...
# 16  Nextdoor is a platform to communicate directly...
# 14  Help individuals and organizations connect, sh...
# 12  Hootsuite is a social media management platfor...
# 11  G Translate is a website add-in that leverages...
# 10  To automate the transformation of PDF forms in...
# 9   Facebook is intended to be used for public out...
# 8   DJI drones are designed to provide aerial imag...
# 7   The intended use of ArcGIS is to support the c...
# 6   Drones are designed to provide aerial imaging,...
# 15  Muck Rack is to enhance public outreach, respo...
# 13  To share information and connect with the comm...
#
#                                            q4_context  \
# 20                      Information exchange software
# 0   The weapons detection system is a part of the ...
# 5   The model is incorporated into the hospital’s ...
# 4   Within the existing pathology reporting workfl...
# 27  The tool is used in coding workflows where cod...
# 2   Mirai is integrated into existing mammography ...
# 1   Rapid AI integrates into clinical stroke workf...
# 3   The technology is deployed in the context of r...
# 25  The technology is specifically designed for do...
# 24  The technology is intended to reduce investiga...
# 23  The technologiesóRedaction Assistant, Auto-Tra...
# 22                            Transcription services.
# 21  ï Used exclusively within the PLX product for ...
# 26  Urban environments or designated coverage area...
# 19  Public communications, education, city announc...
# 18  Deployed for communication and public engagement.
# 17  The Skydio 10X Drone is intended to be used fo...
# 16  Nextdoor is a platform to communicate directly...
# 14  Workforce development, professional outreach, ...
# 12     Hootsuite is used for social media management.
# 11  G Translate is intended to be used for digital...
# 10  Used for digital service delivery of forms, co...
# 9   Facebook serves as a real-time communication t...
# 8   Drones are primarily used for aerial photograp...
# 7   Deployed for mapping, program and asset manage...
# 6   The ANZU Raptor Drone is intended to be used f...
# 15  Muck Rack is to enhance public outreach, respo...
# 13  Instagram is used in the context of public com...
#
#                                     q5_ training_data  \
# 20  raw 311 request data (no personal identifying ...
# 0   According to the Evolv website, the "AI model ...
# 5   This model was trained and validated on EHR da...
# 4   The tool uses rule-based natural language proc...
# 27  Solventumís AI modeling process relies on hist...
# 2   Mirai was trained on mammograms from a large, ...
# 1   The system is a clinically oriented radiologic...
# 3   The model is trained on extensive, anonymized,...
# 25  Our technology is trained on a proprietary dat...
# 24  VehicleManager AI is from Motorola Solutions. ...
# 23  By default, Axon mainly uses data that's self-...
# 22  We are using pre-trained models. We have not s...
# 21  ï Utilizes Microsoft Azure AI transcription, c...
# 26  Acoustic data of gunfire and non-gunfire impul...
# 19  Public user behavior data, video metadata, use...
# 18  X uses AI through its integration with X AI's ...
# 17  The Skydio X10 drone's advanced autonomous cap...
# 16  Nextdoor trains its AI models using a combinat...
# 14  Profile information, activity logs, user inter...
# 12  Hootsuite's OwlyGPT, an AI co-pilot for market...
# 11  G Translate |Google Translate AI is trained us...
# 10  Form Assembly does not train its own AI. It us...
# 9   Facebook uses a combination of sources are use...
# 8   In the DJI drone ecosystem, AI training is ena...
# 7   Most tools are trained on public datasets, pro...
# 6   The Anzu Raptor drone’s AI is designed to supp...
# 15  Most tools are trained on public datasets, pro...
# 13  Meta, the parent company of Instagram, utilize...
#
#                                       q6_how_it_works  \
# 20  machine learning algorithms analyze the most r...
# 0   It combines advanced sensor technology, real-t...
# 5   The core of this technology is a Gradient Boos...
# 4   This AI engine employs rule-based natural lang...
# 27  The 360 Encompass tool integrates with Epic to...
# 2   Mirai uses deep learning to transform each mam...
# 1   Rapid AI automatically processes CT or MRI per...
# 3   TalView operates by capturing video, audio, an...
# 25  Data Ingestion Process: We turn raw vehicle im...
# 24  When a vehicle is detected, AI will analyze th...
# 23  Redaction: AI for redaction in Axon products i...
# 22  We send audio files into aiAssist, which gener...
# 21  ï PLX users choose to transcribe audio or tran...
# 26  ï Detection: Acoustic sensors detect impulsive...
# 19  Uses AI to recommend videos based on engagemen...
# 18  X is a real-time, microblogging and social net...
# 17  The Skydio X10 drone is a cutting-edge autonom...
# 16  The system uses algorithms sometimes AI-powere...
# 14  AI/ML algorithms suggest connections, jobs, an...
# 12  Hootsuite is a social media management platfor...
# 11  G Translate, powered by Google Translate, uses...
# 10  Users upload a PDF; the integrated AI interpre...
# 9   Facebook is a social networking platform power...
# 8   Range and stability analysis: At 7 km, it outp...
# 7   ArcGIS (developed by Esri) is a powerful Geogr...
# 6   The Anzu Raptor Drone works by combining advan...
# 15  Muck Rack is to enhance public outreach, respo...
# 13  Instagram is a multimedia social networking pl...
#
#                                        q7_output_data  \
# 20  statistical model weights, and suggested servi...
# 0   Weapon signatures and images collected on site...
# 5   The model provides a daily estimated probabili...
# 4   The system generates real-time alerts or flags...
# 27  The tool generates suggested diagnoses and pro...
# 2   The model instantly generates a risk score/per...
# 1   Rapid AI generates user-friendly scans highlig...
# 3   During each exam, the system generates detaile...
# 25  The data generated by the offline process: ? V...
# 24  The VehicleManager AI will generate a number o...
# 23  Redaction: AI for redaction in Axon products i...
# 22  Speech recognized words, timings, and speaker ...
# 21  ï The technology returns machine-based transla...
# 26  ï Gunfire incident metadata: time, street addr...
# 19  Engagement metrics (views, likes), user commen...
# 18  X generates real-time data based on user activ...
# 17  The Skydio X10 Drone is a high-performance, AI...
# 16  Nextdoor generates various types of data throu...
# 14  User engagement data, profile updates, connect...
# 12  Hootsuite generates a range of data related to...
# 11  G Translate | Google Translate (also used in w...
# 10        Structured response data from online forms.
# 9   Facebook generates a wide range of data based ...
# 8   DJI drones generate a wide range of flight, vi...
# 7   ArcGIS, a geographic information system (GIS) ...
# 6   Anzu Raptor drones generate a comprehensive ra...
# 15  Muck Rack is a public relations (PR) and media...
# 13  Instagram generates both user-created content ...
#
#                              q8_optimization_accuracy  ...  \
# 20  model is trained (and frequently retrained) to...  ...
# 0   Internally, Express uses machine learning mode...  ...
# 5   The technology optimizes for fewer 30-day unpl...  ...
# 4   This technology aims to identify and capture a...  ...
# 27  The tool seeks to optimize coding accuracy and...  ...
# 2   Mirai aims to shorten wait times for high-risk...  ...
# 1   Rapid AI is primarily aimed at reducing the ti...  ...
# 3   The technology is optimized to identify and fl...  ...
# 25  We are optimizing both accuracy and speed for ...  ...
# 24  We are optimizing both accuracy and speed for ...  ...
# 23  Redaction: streamlines the ability to detect a...  ...
# 22  Itís optimized to reduce the word error rate (...  ...
# 21  ï PLX uses Microsoft Azure AI speech-to-text. ...  ...
# 26  Optimized for fast, accurate detection and loc...  ...
# 19  Engagement, watch time, ad revenue. Accuracy i...  ...
# 18  Optimized for automation speed, pattern recogn...  ...
# 17  Optimized for automation speed, pattern recogn...  ...
# 16  Optimized for automation speed, pattern recogn...  ...
# 14  Connection relevance, job match rates, content...  ...
# 12  Optimized for automation speed, pattern recogn...  ...
# 11  Optimized for automation speed, pattern recogn...  ...
# 10  Optimized for accurate field detection from PD...  ...
# 9   Optimized for automation speed, pattern recogn...  ...
# 8   Optimized for automation speed, pattern recogn...  ...
# 7   Optimized for automation speed, pattern recogn...  ...
# 6   Optimized for automation speed, pattern recogn...  ...
# 15  Optimized for automation speed, pattern recogn...  ...
# 13  Optimized for automation speed, pattern recogn...  ...
#
#                                   q15_human_oversight  \
# 20                                                NaN
# 0   Evolv system will alert security staff of the ...
# 5   Providers receive ongoing training to integrat...
# 4   Human oversight occurs throughout the process,...
# 27  Coders must manually accept or reject each sug...
# 2   Clinicians continue reading mammograms as usua...
# 1   Clinicians ultimately decide on diagnosing and...
# 3   The system is implemented with robust human ov...
# 25  Our human oversight is a continuous improvemen...
# 24  Users determine when to perform searches, what...
# 23  Axon prioritizes responsible AI deployment by ...
# 22  For FirstDraft jobs, there is no human oversig...
# 21  ï The SFPD system is hosted on-premises; PenLi...
# 26  High. All alerts are verified by trained human...
# 19  Mixed: automated moderation plus human review ...
# 18  High level of human-in-the-loop oversight. Req...
# 17  Medium to High level of human-in the loop. Aut...
# 16  High level of human-in-the-loop oversight. Pos...
# 14  Mixed: AI-assisted recommendations with human ...
# 12  High level of human-in-the-loop oversight. Con...
# 11  Low level of human-in-the-loop oversight. Auto...
# 10  High level of human-in-the-loop oversight.  AI...
# 9   High level of human-in-the-loop oversight. All...
# 8   High level of human-in-the-loop oversight. Fli...
# 7   Medium level of human-in-the-loop. Data layers...
# 6   High level of human-in-the-loop oversight. Ope...
# 15  Medium human-in-the-loop oversight. AI tools a...
# 13  High level of human-in-the-loop oversight. Con...
#
#                           q16_data_reuse_for_training  \
# 20  the machine learning models are highly specifi...
# 0   DPH does not allow personally identifiable inf...
# 5   DPH does not allow personally identifiable inf...
# 4   DPH does not allow personally identifiable inf...
# 27  DPH does not allow personally identifiable inf...
# 2   DPH does not allow personally identifiable inf...
# 1   DPH does not allow personally identifiable inf...
# 3   DPH does not allow personally identifiable inf...
# 25  Our use of data for training is based entirely...
# 24  Motorola Solutions does not use public safety ...
# 23  Police data is sensitive in nature, so it is e...
# 22  VIQ does not use customer data to train any th...
# 21  ï No data is stored on external servers for tr...
# 26  Audio snippets and metadata may be used to imp...
# 19  No. Unauthorized use of City Data by Contracto...
# 18  No. Unauthorized use of City Data by Contracto...
# 17  Skydio provides open APIs and developer tools ...
# 16  No. Unauthorized use of City Data by Contracto...
# 14  No. Unauthorized use of City Data by Contracto...
# 12  No. Unauthorized use of City Data by Contracto...
# 11  No. Unauthorized use of City Data by Contracto...
# 10  No. Form Assembly does not use user-submitted ...
# 9   No. Unauthorized use of City Data by Contracto...
# 8   No. In the DJI drone ecosystem, AI training is...
# 7   No. Unauthorized use of City Data by Contracto...
# 6   No Unauthorized use of City Data by Contractor...
# 15  No. Unauthorized use of City Data by Contracto...
# 13  No. Unauthorized use of City Data by Contracto...
#
#                                             q17_users  \
# 20                                                NaN
# 0   Intended users are the San Francisco Sheriff’s...
# 5   The primary audience includes inpatient and ou...
# 4   The primary patient community includes those w...
# 27  All patients under SFDPH may be impacted throu...
# 2   This includes women 30+ coming for mammograms ...
# 1   Individuals presenting with stroke symptoms co...
# 3   The technology interacts primarily with job ca...
# 25  The primary users of our detailed vehicle data...
# 24  The technology is for use by public safety age...
# 23  Persons or objects recorded in video/audio. Pe...
# 22  Entities where audio and video data are captur...
# 21  ï Access to translations, transcriptions, and ...
# 26  ï Law enforcement officers and dispatchers as ...
# 19  General public, content creators, educators, c...
# 18  People of all demographics use X but use varie...
# 17  Drones are internally managed and operated by ...
# 16  Nextdoor is designed for use in the neighborho...
# 14  Job seekers, recruiters, HR professionals, pro...
# 12  Hootsuite is used internally by SFPUC for soci...
# 11  G Translate | Google Translate interacts with ...
# 10  City staff, residents, and external partners s...
# 9   People of all demographics use Facebook but us...
# 8   Drones are internally managed and operated by ...
# 7   General public and city departments utilize Ar...
# 6   Drones are internally managed and operated by ...
# 15  Internal media alerts system use for brand man...
# 13  People of all demographics use Instagram but u...
#
#                           q18_public_or_worker_impact  \
# 20                                                NaN
# 0   ZSFG has developed multiple workplace safety i...
# 5   The technology does not limit or deny care to ...
# 4   The tool’s core function is to ensure accurate...
# 27  The intake form indicates that no additional p...
# 2   Since only select high-risk patients receive e...
# 1   The use of Rapid AI exclusively affects stroke...
# 3   While the system generates AI flags that guide...
# 25  An error in identifying a vehicle's attributes...
# 24  The technology is used to identify vehicles-of...
# 23  Based on Axonís Responsible Innovation Framewo...
# 22  The speech recognition and editing processes a...
# 21  ï The technology enhances existing collected c...
# 26  ï Designed to increase public safety by improv...
# 19  Can shape public perception, access to informa...
# 18  Information shared by SFPUC through X may dire...
# 17  SFPUC drone data can improve public rights by ...
# 16  The San Francisco Public Utilities Commission ...
# 14  Can affect hiring opportunities, professional ...
# 12  Hootsuite may impact public rights if not mana...
# 11  G Translate | Google Translate, when used on S...
# 10  The City ensures accessibility and equity as p...
# 9   Information shared by SFPUC through Facebook m...
# 8   SFPUC drone data can improve public rights by ...
# 7   ArcGIS supports SFPUC’s ability to map, analyz...
# 6   SFPUC drone data can improve public rights by ...
# 15  While Muck Rack aims to support journalists an...
# 13  Information shared by SFPUC through Instagram ...
#
#                                     q19_accessibility  \
# 20                                                NaN
# 0   For all SFDPH users who require assistive tech...
# 5   Because the model is accessed through the Epic...
# 4   For all SFDPH users who require assistive tech...
# 27  For all SFDPH users who require assistive tech...
# 2   For SFDPH staff requiring assistive technologi...
# 1   For any SFDPH staff requiring assistive techno...
# 3   For users requiring assistive technologies, th...
# 25  Our service platform is fully accessible to pe...
# 24  Speech-to-text accessibility solutions can be ...
# 23  At Axon, we are committed to delivering access...
# 22  We typically deliver documents back to custome...
# 21  ï PLX is a visual analytical tool with user in...
# 26  The main user interface is for trained law enf...
# 19  Supports captions, screen readers, and keyboar...
# 18  X (formerly Twitter) offers several accessibil...
# 17  Drones used by SFPUC do not have direct user i...
# 16  Nextdoor does not publicly claim full WCAG 2.1...
# 14  Compatible with screen readers, keyboard navig...
# 12  Hootsuite supports accessibility for people wi...
# 11  G Translate | Google Translate, including its ...
# 10  Not addressed. Must ensure compatibility with ...
# 9   Facebook supports accessibility for people wit...
# 8   Drones used by SFPUC do not have direct user i...
# 7   ArcGIS (by Esri) provides partial accessibilit...
# 6   Drones used by SFPUC do not have direct user i...
# 15  Muck Rack's user interface is primarily design...
# 13  Instagram offers several built-in accessibilit...
#
#                                        q20_job_impact  \
# 20                                                NaN
# 0                                                 No.
# 5   The model is designed to complement clinical w...
# 4   This technology is not expected to replace any...
# 27  This technology is not expected to replace any...
# 2   There is no indication of staff replacement. M...
# 1   This technology is not expected to replace any...
# 3   The technology is not expected to replace any ...
# 25  This technology is not designed to replace per...
# 24  The technology speeds up the process of identi...
# 23  The goal of this technology is not to replace ...
# 22  The technology is used to make the transcripti...
# 21  ï The technology does not replace jobs but imp...
# 26  ShotSpotter is not designed to replace human j...
# 19  No. Technology reduces the need for traditiona...
# 18                        No jobs will be eliminated.
# 17                        No jobs will be eliminated.
# 16                        No jobs will be eliminated.
# 14  No. May automate aspects of recruiting and red...
# 12                        No jobs will be eliminated.
# 11                        No jobs will be eliminated.
# 10  No jobs will be eliminated. Staff time may shi...
# 9                         No jobs will be eliminated.
# 8                         No jobs will be eliminated.
# 7                         No jobs will be eliminated.
# 6                         No jobs will be eliminated.
# 15                        No jobs will be eliminated.
# 13                        No jobs will be eliminated.
#
#                             q21_why_the_city_needs_it  \
# 20                                                NaN
# 0   The weapons detection system is a part of the ...
# 5   Reducing unplanned readmissions for heart fail...
# 4   The tool supports SFDPH objectives by improvin...
# 27  The solution affects all patients within SFDPH...
# 2   By offering faster diagnostic imaging for high...
# 1   Maintaining a Joint Commission stroke certific...
# 3   Implementing TalView’s AI proctoring system is...
# 25  Accurate identification of make, model, state,...
# 24  VM Assist provides a force multiplier which ca...
# 23  There are several key reasons it is important ...
# 22  This decision should be at the countyís discre...
# 21  ï Enhances investigative efficiency, breaks la...
# 26  Gun violence often goes unreported (80% of inc...
# 19  Useful tool for mass communication, education ...
# 18  X (formerly Twitter) is a vital communication ...
# 17  Drones are a critical tool for SFPUC because t...
# 16  To communicate directly with residents in the ...
# 14  Useful tool for civic recruitment, workforce o...
# 12  Social media management is critical to support...
# 11  Provides equitable communication to diverse po...
# 10  Improves efficiency in service delivery, acces...
# 9   Facebook is a vital communication tool for SFP...
# 8   Drones are a critical tool for SFPUC because t...
# 7   ArcGIS is a core geospatial platform used by S...
# 6   Drones are a critical tool for SFPUC because t...
# 15  Muck Rack is an essential media monitoring and...
# 13  Instagram is a vital communication tool for SF...
#
#                             q22_risks_and_mitigations  data_as_of  \
# 20                                                NaN  2025/07/15
# 0   The potential “harms” from a false positive de...  2025/07/15
# 5   Potential risks include overlooking high-risk ...  2025/07/15
# 4   The main risks involve missed or inaccurate ca...  2025/07/15
# 27  The main risk is incorrect code acceptance, wh...  2025/08/01
# 2   Potential risks include labeling too many pati...  2025/07/15
# 1   Potential risks center on incomplete imaging d...  2025/07/15
# 3   The primary risk is the potential for non-prob...  2025/07/15
# 25  Risk: Misidentifying a vehicle (e.g. wrong sta...  2025/07/22
# 24  The biggest risk with any LLM technology is de...  2025/07/22
# 23  The primary risks associated with the use of t...  2025/07/21
# 22  Speech recognition is a process with an inhere...  2025/07/21
# 21  ï As an on-premises solution, San Francisco PD...  2025/07/17
# 26  Risks: ï False positives or missed detections....  2025/07/29
# 19  Misinformation, privacy breaches, algorithmic ...  2025/07/15
# 18  X presents risks such as reduced content reach...  2025/07/15
# 17  The Skydio X10 drone presents several risks, i...  2025/07/15
# 16  Nextdoor poses risks such as algorithmic bias,...  2025/07/15
# 14  Bias in hiring, data misuse, platform manipula...  2025/07/15
# 12  Hootsuite poses risks like account compromise,...  2025/07/15
# 11  G Translate | Google Translate  carries risks ...  2025/07/15
# 10  Inaccurate form parsing, accessibility issues,...  2025/07/15
# 9   Facebook risks include algorithm-driven visibi...  2025/07/15
# 8   DJI drones pose risks such as data privacy con...  2025/07/15
# 7   ArcGIS risks involve the presentation of outda...  2025/07/15
# 6   Anzu Raptor drones pose risks such as data bre...  2025/07/15
# 15  Muck Rack may pose risks related to inaccurate...  2025/07/15
# 13  Instagram risks include visual content inacces...  2025/07/15
#
#    data_loaded_at
# 20     2025/07/18
# 0      2025/07/18
# 5      2025/07/18
# 4      2025/07/18
# 27     2025/08/18
# 2      2025/07/18
# 1      2025/07/18
# 3      2025/07/18
# 25     2025/08/18
# 24     2025/08/18
# 23     2025/08/18
# 22     2025/08/18
# 21     2025/08/18
# 26     2025/08/18
# 19     2025/07/18
# 18     2025/07/18
# 17     2025/07/18
# 16     2025/07/18
# 14     2025/07/18
# 12     2025/07/18
# 11     2025/07/18
# 10     2025/07/18
# 9      2025/07/18
# 8      2025/07/18
# 7      2025/07/18
# 6      2025/07/18
# 15     2025/07/18
# 13     2025/07/18
#
# [28 rows x 26 columns]

# %%
df[0:5] #slice by rows
# Out:
#                                               id department  \
# 0  DPH-Evolv Express concealed weapons detection        DPH
# 1                       DPH-Ischemaview Rapid AI        DPH
# 2                                      DPH-Mirai        DPH
# 3                                    DPH-TalView        DPH
# 4                   DPH-TransMed Inspirata Epath        DPH
#
#                          q1_tool_vendor_name  \
# 0  Evolv Express concealed weapons detection
# 1                       Ischemaview Rapid AI
# 2                                      Mirai
# 3                                    TalView
# 4                   TransMed Inspirata Epath
#
#                                          q2_ purpose  \
# 0  Evolv Express is a next-generation, AI-powered...
# 1  Rapid AI is used to identify and guide treatme...
# 2  Mirai is an AI tool that identifies high-risk ...
# 3  TalView’s AI proctoring tool is designed to mo...
# 4  This tool is a rule-based system that automate...
#
#                                      q3_intended_use  \
# 0  Concealed weapons (guns and knives) detection ...
# 1  The tool is intended for any individual (inpat...
# 2  The tool is intended for women age 30 and olde...
# 3  The tool is intended for use by HR and proctor...
# 4  The technology is intended to process diagnost...
#
#                                           q4_context  \
# 0  The weapons detection system is a part of the ...
# 1  Rapid AI integrates into clinical stroke workf...
# 2  Mirai is integrated into existing mammography ...
# 3  The technology is deployed in the context of r...
# 4  Within the existing pathology reporting workfl...
#
#                                    q5_ training_data  \
# 0  According to the Evolv website, the "AI model ...
# 1  The system is a clinically oriented radiologic...
# 2  Mirai was trained on mammograms from a large, ...
# 3  The model is trained on extensive, anonymized,...
# 4  The tool uses rule-based natural language proc...
#
#                                      q6_how_it_works  \
# 0  It combines advanced sensor technology, real-t...
# 1  Rapid AI automatically processes CT or MRI per...
# 2  Mirai uses deep learning to transform each mam...
# 3  TalView operates by capturing video, audio, an...
# 4  This AI engine employs rule-based natural lang...
#
#                                       q7_output_data  \
# 0  Weapon signatures and images collected on site...
# 1  Rapid AI generates user-friendly scans highlig...
# 2  The model instantly generates a risk score/per...
# 3  During each exam, the system generates detaile...
# 4  The system generates real-time alerts or flags...
#
#                             q8_optimization_accuracy  ...  \
# 0  Internally, Express uses machine learning mode...  ...
# 1  Rapid AI is primarily aimed at reducing the ti...  ...
# 2  Mirai aims to shorten wait times for high-risk...  ...
# 3  The technology is optimized to identify and fl...  ...
# 4  This technology aims to identify and capture a...  ...
#
#                                  q15_human_oversight  \
# 0  Evolv system will alert security staff of the ...
# 1  Clinicians ultimately decide on diagnosing and...
# 2  Clinicians continue reading mammograms as usua...
# 3  The system is implemented with robust human ov...
# 4  Human oversight occurs throughout the process,...
#
#                          q16_data_reuse_for_training  \
# 0  DPH does not allow personally identifiable inf...
# 1  DPH does not allow personally identifiable inf...
# 2  DPH does not allow personally identifiable inf...
# 3  DPH does not allow personally identifiable inf...
# 4  DPH does not allow personally identifiable inf...
#
#                                            q17_users  \
# 0  Intended users are the San Francisco Sheriff’s...
# 1  Individuals presenting with stroke symptoms co...
# 2  This includes women 30+ coming for mammograms ...
# 3  The technology interacts primarily with job ca...
# 4  The primary patient community includes those w...
#
#                          q18_public_or_worker_impact  \
# 0  ZSFG has developed multiple workplace safety i...
# 1  The use of Rapid AI exclusively affects stroke...
# 2  Since only select high-risk patients receive e...
# 3  While the system generates AI flags that guide...
# 4  The tool’s core function is to ensure accurate...
#
#                                    q19_accessibility  \
# 0  For all SFDPH users who require assistive tech...
# 1  For any SFDPH staff requiring assistive techno...
# 2  For SFDPH staff requiring assistive technologi...
# 3  For users requiring assistive technologies, th...
# 4  For all SFDPH users who require assistive tech...
#
#                                       q20_job_impact  \
# 0                                                No.
# 1  This technology is not expected to replace any...
# 2  There is no indication of staff replacement. M...
# 3  The technology is not expected to replace any ...
# 4  This technology is not expected to replace any...
#
#                            q21_why_the_city_needs_it  \
# 0  The weapons detection system is a part of the ...
# 1  Maintaining a Joint Commission stroke certific...
# 2  By offering faster diagnostic imaging for high...
# 3  Implementing TalView’s AI proctoring system is...
# 4  The tool supports SFDPH objectives by improvin...
#
#                            q22_risks_and_mitigations  data_as_of  \
# 0  The potential “harms” from a false positive de...  2025/07/15
# 1  Potential risks center on incomplete imaging d...  2025/07/15
# 2  Potential risks include labeling too many pati...  2025/07/15
# 3  The primary risk is the potential for non-prob...  2025/07/15
# 4  The main risks involve missed or inaccurate ca...  2025/07/15
#
#   data_loaded_at
# 0     2025/07/18
# 1     2025/07/18
# 2     2025/07/18
# 3     2025/07/18
# 4     2025/07/18
#
# [5 rows x 26 columns]

# %%
df[df['department']>5] # select rows by values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df[df['']>5] # select rows by values
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ''

# %%
# Clean the data

# %%
df.info() # shows the data types and number of null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    28 non-null     object
#  1   department                            28 non-null     object
#  2   q1_tool_vendor_name                   28 non-null     object
#  3   q2_ purpose                           27 non-null     object
#  4   q3_intended_use                       27 non-null     object
#  5   q4_context                            28 non-null     object
#  6   q5_ training_data                     28 non-null     object
#  7   q6_how_it_works                       28 non-null     object
#  8   q7_output_data                        28 non-null     object
#  9   q8_optimization_accuracy              28 non-null     object
#  10  q9_ optimal_conditions                28 non-null     object
#  11  q10_ performance_decrease_conditions  28 non-null     object
#  12  q11_bias_testing                      28 non-null     object
#  13  q12 _reported_issues                  27 non-null     object
#  14  q13_testing_conditions                27 non-null     object
#  15  q14_incident_monitoring               27 non-null     object
#  16  q15_human_oversight                   27 non-null     object
#  17  q16_data_reuse_for_training           28 non-null     object
#  18  q17_users                             27 non-null     object
#  19  q18_public_or_worker_impact           27 non-null     object
#  20  q19_accessibility                     27 non-null     object
#  21  q20_job_impact                        27 non-null     object
#  22  q21_why_the_city_needs_it             27 non-null     object
#  23  q22_risks_and_mitigations             27 non-null     object
#  24  data_as_of                            28 non-null     object
#  25  data_loaded_at                        28 non-null     object
# dtypes: object(26)
# memory usage: 5.8+ KB

# %%
df['date'] = pd.to_datetime(df['dateRep'], format='%d/%m/%Y') #change the data type to date with specific format
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dateRep'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['date'] = pd.to_datetime(df['dateRep'], format='%d/%m/%Y') #change the data type to date with specific format
#       2 df.info()
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'dateRep'

# %%
#rename columns
df = df.rename(columns={"popData2019": "pop", "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000": "cum","countriesAndTerritories":"country" }) 
df.head()
# Out:
#                                               id department  \
# 0  DPH-Evolv Express concealed weapons detection        DPH
# 1                       DPH-Ischemaview Rapid AI        DPH
# 2                                      DPH-Mirai        DPH
# 3                                    DPH-TalView        DPH
# 4                   DPH-TransMed Inspirata Epath        DPH
#
#                          q1_tool_vendor_name  \
# 0  Evolv Express concealed weapons detection
# 1                       Ischemaview Rapid AI
# 2                                      Mirai
# 3                                    TalView
# 4                   TransMed Inspirata Epath
#
#                                          q2_ purpose  \
# 0  Evolv Express is a next-generation, AI-powered...
# 1  Rapid AI is used to identify and guide treatme...
# 2  Mirai is an AI tool that identifies high-risk ...
# 3  TalView’s AI proctoring tool is designed to mo...
# 4  This tool is a rule-based system that automate...
#
#                                      q3_intended_use  \
# 0  Concealed weapons (guns and knives) detection ...
# 1  The tool is intended for any individual (inpat...
# 2  The tool is intended for women age 30 and olde...
# 3  The tool is intended for use by HR and proctor...
# 4  The technology is intended to process diagnost...
#
#                                           q4_context  \
# 0  The weapons detection system is a part of the ...
# 1  Rapid AI integrates into clinical stroke workf...
# 2  Mirai is integrated into existing mammography ...
# 3  The technology is deployed in the context of r...
# 4  Within the existing pathology reporting workfl...
#
#                                    q5_ training_data  \
# 0  According to the Evolv website, the "AI model ...
# 1  The system is a clinically oriented radiologic...
# 2  Mirai was trained on mammograms from a large, ...
# 3  The model is trained on extensive, anonymized,...
# 4  The tool uses rule-based natural language proc...
#
#                                      q6_how_it_works  \
# 0  It combines advanced sensor technology, real-t...
# 1  Rapid AI automatically processes CT or MRI per...
# 2  Mirai uses deep learning to transform each mam...
# 3  TalView operates by capturing video, audio, an...
# 4  This AI engine employs rule-based natural lang...
#
#                                       q7_output_data  \
# 0  Weapon signatures and images collected on site...
# 1  Rapid AI generates user-friendly scans highlig...
# 2  The model instantly generates a risk score/per...
# 3  During each exam, the system generates detaile...
# 4  The system generates real-time alerts or flags...
#
#                             q8_optimization_accuracy  ...  \
# 0  Internally, Express uses machine learning mode...  ...
# 1  Rapid AI is primarily aimed at reducing the ti...  ...
# 2  Mirai aims to shorten wait times for high-risk...  ...
# 3  The technology is optimized to identify and fl...  ...
# 4  This technology aims to identify and capture a...  ...
#
#                                  q15_human_oversight  \
# 0  Evolv system will alert security staff of the ...
# 1  Clinicians ultimately decide on diagnosing and...
# 2  Clinicians continue reading mammograms as usua...
# 3  The system is implemented with robust human ov...
# 4  Human oversight occurs throughout the process,...
#
#                          q16_data_reuse_for_training  \
# 0  DPH does not allow personally identifiable inf...
# 1  DPH does not allow personally identifiable inf...
# 2  DPH does not allow personally identifiable inf...
# 3  DPH does not allow personally identifiable inf...
# 4  DPH does not allow personally identifiable inf...
#
#                                            q17_users  \
# 0  Intended users are the San Francisco Sheriff’s...
# 1  Individuals presenting with stroke symptoms co...
# 2  This includes women 30+ coming for mammograms ...
# 3  The technology interacts primarily with job ca...
# 4  The primary patient community includes those w...
#
#                          q18_public_or_worker_impact  \
# 0  ZSFG has developed multiple workplace safety i...
# 1  The use of Rapid AI exclusively affects stroke...
# 2  Since only select high-risk patients receive e...
# 3  While the system generates AI flags that guide...
# 4  The tool’s core function is to ensure accurate...
#
#                                    q19_accessibility  \
# 0  For all SFDPH users who require assistive tech...
# 1  For any SFDPH staff requiring assistive techno...
# 2  For SFDPH staff requiring assistive technologi...
# 3  For users requiring assistive technologies, th...
# 4  For all SFDPH users who require assistive tech...
#
#                                       q20_job_impact  \
# 0                                                No.
# 1  This technology is not expected to replace any...
# 2  There is no indication of staff replacement. M...
# 3  The technology is not expected to replace any ...
# 4  This technology is not expected to replace any...
#
#                            q21_why_the_city_needs_it  \
# 0  The weapons detection system is a part of the ...
# 1  Maintaining a Joint Commission stroke certific...
# 2  By offering faster diagnostic imaging for high...
# 3  Implementing TalView’s AI proctoring system is...
# 4  The tool supports SFDPH objectives by improvin...
#
#                            q22_risks_and_mitigations  data_as_of  \
# 0  The potential “harms” from a false positive de...  2025/07/15
# 1  Potential risks center on incomplete imaging d...  2025/07/15
# 2  Potential risks include labeling too many pati...  2025/07/15
# 3  The primary risk is the potential for non-prob...  2025/07/15
# 4  The main risks involve missed or inaccurate ca...  2025/07/15
#
#   data_loaded_at
# 0     2025/07/18
# 1     2025/07/18
# 2     2025/07/18
# 3     2025/07/18
# 4     2025/07/18
#
# [5 rows x 26 columns]

# %%
df.isnull().sum() #show the number of rows containing null value
# Out:
# id                                      0
# department                              0
# q1_tool_vendor_name                     0
# q2_ purpose                             1
# q3_intended_use                         1
# q4_context                              0
# q5_ training_data                       0
# q6_how_it_works                         0
# q7_output_data                          0
# q8_optimization_accuracy                0
# q9_ optimal_conditions                  0
# q10_ performance_decrease_conditions    0
# q11_bias_testing                        0
# q12 _reported_issues                    1
# q13_testing_conditions                  1
# q14_incident_monitoring                 1
# q15_human_oversight                     1
# q16_data_reuse_for_training             0
# q17_users                               1
# q18_public_or_worker_impact             1
# q19_accessibility                       1
# q20_job_impact                          1
# q21_why_the_city_needs_it               1
# q22_risks_and_mitigations               1
# data_as_of                              0
# data_loaded_at                          0
# dtype: int64

# %%
df = df.dropna() #drop null values
df.isnull().sum()
# Out:
# id                                      0
# department                              0
# q1_tool_vendor_name                     0
# q2_ purpose                             0
# q3_intended_use                         0
# q4_context                              0
# q5_ training_data                       0
# q6_how_it_works                         0
# q7_output_data                          0
# q8_optimization_accuracy                0
# q9_ optimal_conditions                  0
# q10_ performance_decrease_conditions    0
# q11_bias_testing                        0
# q12 _reported_issues                    0
# q13_testing_conditions                  0
# q14_incident_monitoring                 0
# q15_human_oversight                     0
# q16_data_reuse_for_training             0
# q17_users                               0
# q18_public_or_worker_impact             0
# q19_accessibility                       0
# q20_job_impact                          0
# q21_why_the_city_needs_it               0
# q22_risks_and_mitigations               0
# data_as_of                              0
# data_loaded_at                          0
# dtype: int64

# %%
df.describe() #statistical summary of the data
# Out:
#                                  id department      q1_tool_vendor_name  \
# count                            27         27                       27
# unique                           26          3                       26
# top     POL-Motorola Solutions Inc.      SFPUC  Motorola Solutions Inc.
# freq                              2         14                        2
#
#                                               q2_ purpose  \
# count                                                  27
# unique                                                 26
# top     Drones are designed to provide aerial imaging,...
# freq                                                    2
#
#                                           q3_intended_use  \
# count                                                  27
# unique                                                 26
# top     Drones are designed to provide aerial imaging,...
# freq                                                    2
#
#                                                q4_context  \
# count                                                  27
# unique                                                 27
# top     The weapons detection system is a part of the ...
# freq                                                    1
#
#                                         q5_ training_data  \
# count                                                  27
# unique                                                 26
# top     Most tools are trained on public datasets, pro...
# freq                                                    2
#
#                                           q6_how_it_works  \
# count                                                  27
# unique                                                 27
# top     It combines advanced sensor technology, real-t...
# freq                                                    1
#
#                                            q7_output_data  \
# count                                                  27
# unique                                                 27
# top     Weapon signatures and images collected on site...
# freq                                                    1
#
#                                  q8_optimization_accuracy  ...  \
# count                                                  27  ...
# unique                                                 19  ...
# top     Optimized for automation speed, pattern recogn...  ...
# freq                                                    9  ...
#
#                                       q15_human_oversight  \
# count                                                  27
# unique                                                 27
# top     Evolv system will alert security staff of the ...
# freq                                                    1
#
#                               q16_data_reuse_for_training  \
# count                                                  27
# unique                                                 14
# top     No. Unauthorized use of City Data by Contracto...
# freq                                                   10
#
#                                                 q17_users  \
# count                                                  27
# unique                                                 25
# top     Drones are internally managed and operated by ...
# freq                                                    3
#
#                               q18_public_or_worker_impact  \
# count                                                  27
# unique                                                 25
# top     SFPUC drone data can improve public rights by ...
# freq                                                    3
#
#                                         q19_accessibility  \
# count                                                  27
# unique                                                 23
# top     For all SFDPH users who require assistive tech...
# freq                                                    3
#
#                      q20_job_impact  \
# count                            27
# unique                           16
# top     No jobs will be eliminated.
# freq                             11
#
#                                 q21_why_the_city_needs_it  \
# count                                                  27
# unique                                                 25
# top     Drones are a critical tool for SFPUC because t...
# freq                                                    3
#
#                                 q22_risks_and_mitigations  data_as_of  \
# count                                                  27          27
# unique                                                 27           6
# top     The potential “harms” from a false positive de...  2025/07/15
# freq                                                    1          20
#
#        data_loaded_at
# count              27
# unique              2
# top        2025/07/18
# freq               20
#
# [4 rows x 26 columns]

# %%
df = df[(df['department']>=0) & (df['id']>=0) & (df['q1_tool_vendor_name']>=0)] #filter data
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df = df[(df['department']>=0) & (df['id']>=0) & (df['q1_tool_vendor_name']>=0)] #filter data
#       2 df.describe()
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
df['department'].value_counts() #show the count of unique values
# Out:
# department
# SFPUC    14
# DPH       7
# POL       6
# Name: count, dtype: int64

# %%
df = df[['country','cases','deaths','pop','cum','date']] # keep specific columns 
df.head()

# %%
df.set_index('id',inplace=True) #define the index
df.head()
# Out:
#                                               department  \
# id
# DPH-Evolv Express concealed weapons detection        DPH
# DPH-Ischemaview Rapid AI                             DPH
# DPH-Mirai                                            DPH
# DPH-TalView                                          DPH
# DPH-TransMed Inspirata Epath                         DPH
#
#                                                                      q1_tool_vendor_name  \
# id
# DPH-Evolv Express concealed weapons detection  Evolv Express concealed weapons detection
# DPH-Ischemaview Rapid AI                                            Ischemaview Rapid AI
# DPH-Mirai                                                                          Mirai
# DPH-TalView                                                                      TalView
# DPH-TransMed Inspirata Epath                                    TransMed Inspirata Epath
#
#                                                                                      q2_ purpose  \
# id
# DPH-Evolv Express concealed weapons detection  Evolv Express is a next-generation, AI-powered...
# DPH-Ischemaview Rapid AI                       Rapid AI is used to identify and guide treatme...
# DPH-Mirai                                      Mirai is an AI tool that identifies high-risk ...
# DPH-TalView                                    TalView’s AI proctoring tool is designed to mo...
# DPH-TransMed Inspirata Epath                   This tool is a rule-based system that automate...
#
#                                                                                  q3_intended_use  \
# id
# DPH-Evolv Express concealed weapons detection  Concealed weapons (guns and knives) detection ...
# DPH-Ischemaview Rapid AI                       The tool is intended for any individual (inpat...
# DPH-Mirai                                      The tool is intended for women age 30 and olde...
# DPH-TalView                                    The tool is intended for use by HR and proctor...
# DPH-TransMed Inspirata Epath                   The technology is intended to process diagnost...
#
#                                                                                       q4_context  \
# id
# DPH-Evolv Express concealed weapons detection  The weapons detection system is a part of the ...
# DPH-Ischemaview Rapid AI                       Rapid AI integrates into clinical stroke workf...
# DPH-Mirai                                      Mirai is integrated into existing mammography ...
# DPH-TalView                                    The technology is deployed in the context of r...
# DPH-TransMed Inspirata Epath                   Within the existing pathology reporting workfl...
#
#                                                                                q5_ training_data  \
# id
# DPH-Evolv Express concealed weapons detection  According to the Evolv website, the "AI model ...
# DPH-Ischemaview Rapid AI                       The system is a clinically oriented radiologic...
# DPH-Mirai                                      Mirai was trained on mammograms from a large, ...
# DPH-TalView                                    The model is trained on extensive, anonymized,...
# DPH-TransMed Inspirata Epath                   The tool uses rule-based natural language proc...
#
#                                                                                  q6_how_it_works  \
# id
# DPH-Evolv Express concealed weapons detection  It combines advanced sensor technology, real-t...
# DPH-Ischemaview Rapid AI                       Rapid AI automatically processes CT or MRI per...
# DPH-Mirai                                      Mirai uses deep learning to transform each mam...
# DPH-TalView                                    TalView operates by capturing video, audio, an...
# DPH-TransMed Inspirata Epath                   This AI engine employs rule-based natural lang...
#
#                                                                                   q7_output_data  \
# id
# DPH-Evolv Express concealed weapons detection  Weapon signatures and images collected on site...
# DPH-Ischemaview Rapid AI                       Rapid AI generates user-friendly scans highlig...
# DPH-Mirai                                      The model instantly generates a risk score/per...
# DPH-TalView                                    During each exam, the system generates detaile...
# DPH-TransMed Inspirata Epath                   The system generates real-time alerts or flags...
#
#                                                                         q8_optimization_accuracy  \
# id
# DPH-Evolv Express concealed weapons detection  Internally, Express uses machine learning mode...
# DPH-Ischemaview Rapid AI                       Rapid AI is primarily aimed at reducing the ti...
# DPH-Mirai                                      Mirai aims to shorten wait times for high-risk...
# DPH-TalView                                    The technology is optimized to identify and fl...
# DPH-TransMed Inspirata Epath                   This technology aims to identify and capture a...
#
#                                                                           q9_ optimal_conditions  \
# id
# DPH-Evolv Express concealed weapons detection  Evolv Express systems must be placed in approp...
# DPH-Ischemaview Rapid AI                       Rapid AI will not function if imaging data is ...
# DPH-Mirai                                      Mirai relies on standard four-view mammogram d...
# DPH-TalView                                    For optimal performance, the web-based tool re...
# DPH-TransMed Inspirata Epath                   As long as the system receives pathology data ...
#
#                                                ...  \
# id                                             ...
# DPH-Evolv Express concealed weapons detection  ...
# DPH-Ischemaview Rapid AI                       ...
# DPH-Mirai                                      ...
# DPH-TalView                                    ...
# DPH-TransMed Inspirata Epath                   ...
#
#                                                                              q15_human_oversight  \
# id
# DPH-Evolv Express concealed weapons detection  Evolv system will alert security staff of the ...
# DPH-Ischemaview Rapid AI                       Clinicians ultimately decide on diagnosing and...
# DPH-Mirai                                      Clinicians continue reading mammograms as usua...
# DPH-TalView                                    The system is implemented with robust human ov...
# DPH-TransMed Inspirata Epath                   Human oversight occurs throughout the process,...
#
#                                                                      q16_data_reuse_for_training  \
# id
# DPH-Evolv Express concealed weapons detection  DPH does not allow personally identifiable inf...
# DPH-Ischemaview Rapid AI                       DPH does not allow personally identifiable inf...
# DPH-Mirai                                      DPH does not allow personally identifiable inf...
# DPH-TalView                                    DPH does not allow personally identifiable inf...
# DPH-TransMed Inspirata Epath                   DPH does not allow personally identifiable inf...
#
#                                                                                        q17_users  \
# id
# DPH-Evolv Express concealed weapons detection  Intended users are the San Francisco Sheriff’s...
# DPH-Ischemaview Rapid AI                       Individuals presenting with stroke symptoms co...
# DPH-Mirai                                      This includes women 30+ coming for mammograms ...
# DPH-TalView                                    The technology interacts primarily with job ca...
# DPH-TransMed Inspirata Epath                   The primary patient community includes those w...
#
#                                                                      q18_public_or_worker_impact  \
# id
# DPH-Evolv Express concealed weapons detection  ZSFG has developed multiple workplace safety i...
# DPH-Ischemaview Rapid AI                       The use of Rapid AI exclusively affects stroke...
# DPH-Mirai                                      Since only select high-risk patients receive e...
# DPH-TalView                                    While the system generates AI flags that guide...
# DPH-TransMed Inspirata Epath                   The tool’s core function is to ensure accurate...
#
#                                                                                q19_accessibility  \
# id
# DPH-Evolv Express concealed weapons detection  For all SFDPH users who require assistive tech...
# DPH-Ischemaview Rapid AI                       For any SFDPH staff requiring assistive techno...
# DPH-Mirai                                      For SFDPH staff requiring assistive technologi...
# DPH-TalView                                    For users requiring assistive technologies, th...
# DPH-TransMed Inspirata Epath                   For all SFDPH users who require assistive tech...
#
#                                                                                   q20_job_impact  \
# id
# DPH-Evolv Express concealed weapons detection                                                No.
# DPH-Ischemaview Rapid AI                       This technology is not expected to replace any...
# DPH-Mirai                                      There is no indication of staff replacement. M...
# DPH-TalView                                    The technology is not expected to replace any ...
# DPH-TransMed Inspirata Epath                   This technology is not expected to replace any...
#
#                                                                        q21_why_the_city_needs_it  \
# id
# DPH-Evolv Express concealed weapons detection  The weapons detection system is a part of the ...
# DPH-Ischemaview Rapid AI                       Maintaining a Joint Commission stroke certific...
# DPH-Mirai                                      By offering faster diagnostic imaging for high...
# DPH-TalView                                    Implementing TalView’s AI proctoring system is...
# DPH-TransMed Inspirata Epath                   The tool supports SFDPH objectives by improvin...
#
#                                                                        q22_risks_and_mitigations  \
# id
# DPH-Evolv Express concealed weapons detection  The potential “harms” from a false positive de...
# DPH-Ischemaview Rapid AI                       Potential risks center on incomplete imaging d...
# DPH-Mirai                                      Potential risks include labeling too many pati...
# DPH-TalView                                    The primary risk is the potential for non-prob...
# DPH-TransMed Inspirata Epath                   The main risks involve missed or inaccurate ca...
#
#                                                data_as_of data_loaded_at
# id
# DPH-Evolv Express concealed weapons detection  2025/07/15     2025/07/18
# DPH-Ischemaview Rapid AI                       2025/07/15     2025/07/18
# DPH-Mirai                                      2025/07/15     2025/07/18
# DPH-TalView                                    2025/07/15     2025/07/18
# DPH-TransMed Inspirata Epath                   2025/07/15     2025/07/18
#
# [5 rows x 25 columns]

# %%
df.loc['2020-04-05'] #filter the data based on the index value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: '2020-04-05'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.loc['2020-04-05'] #filter the data based on the index value
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '2020-04-05'

# %%
df.to_csv('clean_data.csv') #store the cleaned data to local computer
